# %%
print "Jane is cool"
# Out:
# Jane is cool

# %%
# %matplotlib inline

# %%
import pyart
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/Michelle/anaconda/lib/python2.7/site-packages/pyart/graph/__init__.py:32: UserWarning: No grid plotting support, requires basemap.
#   warnings.warn('No grid plotting support, requires basemap.')
# /Users/Michelle/anaconda/lib/python2.7/site-packages/pyart/graph/__init__.py:38: UserWarning: No grid plotting support, requires basemap.
#   warnings.warn('No grid plotting support, requires basemap.')

# %%
radar = pyart.io.read('../../../Documents/ANL SULI/NEXRAD Files/KVNX20110520_090333_V06.gz')

# %%
type(radar)
# Out:
# pyart.core.radar.Radar

# %%
type(radar.fields)
# Out:
# dict

# %%
radar.fields.keys()
# Out:
# ['differential_phase',
#  'cross_correlation_ratio',
#  'spectrum_width',
#  'reflectivity',
#  'differential_reflectivity',
#  'velocity']

# %%
plt.figure(figsize = (20,10))
plt.imshow(radar.fields['reflectivity']['data'], aspect = 0.1, origin = 'bottom')
plt.xlabel('range gate')
plt.ylabel('ray number')
